# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

img=cv2.imread('./snack83.jpg')
plt.figure(figsize=(15,12))
plt.imshow(img);

# %%
img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(15,12))
plt.imshow(img_gray);

# %%
img_blur=cv2.GaussianBlur(img_gray,(5,5),0)
plt.figure(figsize=(15,12))
plt.imshow(img_blur);

# %%
ret,img_th=cv2.threshold(img_blur,100,230,cv2.THRESH_BINARY_INV)
contours,hierachy=cv2.findContours(img_th.copy(),cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
rects=[cv2.boundingRect(each) for each in contours]
rects
# Out:
# [(274, 399, 1, 1),
#  (221, 399, 1, 1),
#  (213, 399, 1, 1),
#  (269, 398, 1, 2),
#  (260, 397, 4, 3),
#  (281, 394, 5, 6),
#  (265, 394, 2, 2),
#  (178, 392, 4, 4),
#  (305, 386, 1, 1),
#  (13, 174, 6, 3),
#  (207, 90, 4, 3),
#  (204, 87, 2, 2),
#  (725, 76, 13, 9),
#  (158, 61, 15, 13),
#  (153, 52, 5, 6),
#  (26, 31, 774, 369),
#  (337, 6, 18, 22)]

# %%
tmp=[w*h for (x,y,w,h) in rects]
tmp.sort()
tmp
# Out:
# [1, 1, 1, 1, 2, 4, 4, 12, 12, 16, 18, 30, 30, 117, 195, 396, 285606]
