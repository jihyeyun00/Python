# %%
import pandas as pd
import urllib.request
import requests
from bs4 import BeautifulSoup

# %%
key = "kMp5bNdDlE6%2FAh38y4amt4hwbKsh4JZlPkgj0WmWEHTMfhyE9Sa1Hojx0Jbj4Gi7QXC7jRoWloXcXBsp3QtJgg%3D%3D"
def dataset(key) :
    
    tag_list = ["airfln",'airlineenglish','airlinekorean','airport','arrivedeng',
           'arrivedkor','boardingeng','boardingkor','city','etd','gate',
           'io','line','rmkeng','rmkkor','std']
    
    url = "http://openapi.airport.co.kr/service/rest/FlightStatusList/getFlightStatusList?ServiceKey="+key+"&schStTime=0600&schEdTime=1800&schAirCode=CJU&pageNo=1"
    dataset = []
    for i in tag_list:
        dataList = []
        res = requests.get(url)
        soup = BeautifulSoup(res.content, 'html.parser')
        find_soup = soup.find_all(i)
        for j in find_soup :
            dataList.append(j.get_text())
        dataset.append(dataList)
    return pd.DataFrame(dataset)

dataset = dataset(key)
dataset
# Out:
#                  0               1           2               3  \
# 0           OZ8900          OZ8902       RS901          OZ8901
# 1   ASIANA AIRLINE  ASIANA AIRLINE   AIR SEOUL  ASIANA AIRLINE
# 2           아시아나항공          아시아나항공        에어서울          아시아나항공
# 3              CJU             CJU         CJU             CJU
# 4            GIMPO           GIMPO        JEJU            JEJU
# 5            서울/김포           서울/김포          제주              제주
# 6             JEJU            JEJU       GIMPO           GIMPO
# 7               제주              제주       서울/김포           서울/김포
# 8              GMP             GMP         GMP             GMP
# 9             0636            0652        0701            0704
# 10              10               7          13               6
# 11               O               O           I               I
# 12              국내              국내          국내              국내
# 13        DEPARTED        DEPARTED  ARRIVED         ARRIVED
# 14              출발              출발          도착              도착
# 15            0630            0640        0700            0715
#
#                    4         5                 6                 7  \
# 0              TW801     LJ592             TW811             TW701
# 1   T'WAY AIR CO.LTD    JINAIR  T'WAY AIR CO.LTD  T'WAY AIR CO.LTD
# 2              티웨이항공       진에어             티웨이항공             티웨이항공
# 3                CJU       CJU               CJU               CJU
# 4               JEJU   GWANGJU              JEJU              JEJU
# 5                 제주        광주                제주                제주
# 6              DAEGU      JEJU             DAEGU             GIMPO
# 7                 대구        제주                대구             서울/김포
# 8                TAE       KWJ               TAE               GMP
# 9               0710      0731              0719              0730
# 10                50        3A                51                 9
# 11                 I         O                 I                 I
# 12                국내        국내                국내                국내
# 13        ARRIVED     DEPARTED        ARRIVED           ARRIVED
# 14                도착        출발                도착                도착
# 15              0720      0720              0730              0730
#
#                  8          9
# 0           OZ8903      RS902
# 1   ASIANA AIRLINE  AIR SEOUL
# 2           아시아나항공       에어서울
# 3              CJU        CJU
# 4             JEJU      GIMPO
# 5               제주      서울/김포
# 6            GIMPO       JEJU
# 7            서울/김포         제주
# 8              GMP        GMP
# 9             0725       0745
# 10              10         13
# 11               I          O
# 12              국내         국내
# 13      ARRIVED      DEPARTED
# 14              도착         출발
# 15            0735       0735
