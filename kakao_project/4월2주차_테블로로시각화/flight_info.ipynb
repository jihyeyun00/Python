# %%
import time
import requests
import xml.etree.ElementTree as ET

# API 인증키
API_KEY = "Hl9nCtSJsJYpZKSXI1I4S3Ucr7gOPCG6dCX6BSht44RZMRnxVrw4NdAA07lo6kd9fNT6ThCPql8Ia0a2EBDlbw%3D%3D"
# API 공통파라미터
API_COMMON_PARAMS = {"serviceKey" : requests.utils.unquote(API_KEY), "pageNo" : "1"} # service key가 UTF-8형식이므로 decode하여 넘긴다.(get() 내부에서 encoding됨)

CURRENT_DATE = time.strftime("%Y%m%d") # yyyymmdd
BASE_CITY_CODE = "CJU" # 제주

# API 요청
def get_response_xml(url, params):
    response = requests.get(url, params=params)
    print(response.url)
    print(params)
    
    if response.status_code == 200:
        return ET.fromstring(response.text)
    else:
        return None
    
# xml에서 필요한 데이터만 dict형 배열에 저장
def get_data(result_xml, col_names):
    result_list = []
    
    for item in result_xml.findall("./body/items/item"):
        result = {}
        for xml_col_name, table_col_name in col_names.items():
            result[table_col_name] = item.find(xml_col_name).text
            
        result_list.append(result)
            
    return result_list
    
# 국내선 운항 스케쥴(제주 출발) 조회(/FlightScheduleList/getDflightScheduleList)
def get_departure_schedule_list():
    # 가져올 데이터의 항목명 정의
    col_name = {"airlineKorean" : "airline_name",
                "arrivalcity" : "arrival_city",
                "domesticNum" : "flight_num",
                "domesticArrivalTime" : "arrival_time",
                "domesticStartTime" : "departure_time",
                "domesticStdate" : "start_date",
                "domesticEddate" : "end_date",
                "domesticFri" : "friday_yn"
               }
    params = API_COMMON_PARAMS.copy()
    params["schDate"] = CURRENT_DATE
    params["schDeptCityCode"] = BASE_CITY_CODE
    params["numOfRows"] = 999 # 한번에 출력할 최대 데이터수(*이 값이 상은 안넘어갈거 같아서 우선 대충 설정..)
    url = "http://openapi.airport.co.kr/service/rest/FlightScheduleList/getDflightScheduleList"
    
    result_xml = get_response_xml(url, params)
    
    return get_data(result_xml, col_name)

# 국내선 운항 스케쥴(제주 도착) 조회(/FlightScheduleList/getDflightScheduleList)
def get_arrival_schedule_list():
    col_name = {"airlineKorean" : "airline_name",
                "startcity" : "departure_city",
                "domesticNum" : "flight_num",
                "domesticArrivalTime" : "arrival_time",
                "domesticStartTime" : "departure_time",
                "domesticStdate" : "start_date",
                "domesticEddate" : "end_date",
                "domesticFri" : "friday_yn"
               }
    params = API_COMMON_PARAMS.copy()
    params["schDate"] = CURRENT_DATE
    params["schArrvCityCode"] = BASE_CITY_CODE
    params["numOfRows"] = 999 # 한번에 출력할 최대 데이터수(*이 값이 상은 안넘어갈거 같아서 우선 대충 설정..)
    url = "http://openapi.airport.co.kr/service/rest/FlightScheduleList/getDflightScheduleList"
    
    result_xml = get_response_xml(url, params)
    
    return get_data(result_xml, col_name)

# 실시간 운항정보 조회(/FlightStatusList/getFlightStatusList)
def get_flight_status_list():
    # 가져올 데이터의 항목명
    col_name = {"airFln" : "flight_num",
                "airlineKorean" : "airline_name",
                "airport" : "airport_code",
                "city" : "city_code",
                "arrivedKor" : "arrived_airport_name",
                "boardingKor" : "boarding_airport_name",
                "std" : "scheduled_time",
                "etd" : "estimated_time",
                "io" : "inout_code",
                "rmkEng" : "flight_status_eng",
                "rmkKor" : "flight_status_kor"                
               }
    params = API_COMMON_PARAMS.copy()
    params["schLineType"] = "D" # D:국내
    params["schAirCode"] = BASE_CITY_CODE
    params["numOfRows"] = 999 # 한번에 출력할 최대 데이터수(*이 값이 상은 안넘어갈거 같아서 우선 대충 설정..)
    url = "http://openapi.airport.co.kr/service/rest/FlightStatusList/getFlightStatusList"
    
    result_xml = get_response_xml(url, params)
    
    return get_data(result_xml, col_name)

# %%
departure_list = get_departure_schedule_list()
arrival_list = get_arrival_schedule_list()
status_list = get_flight_status_list()
# Out:
# http://openapi.airport.co.kr/service/rest/FlightScheduleList/getDflightScheduleList?serviceKey=Hl9nCtSJsJYpZKSXI1I4S3Ucr7gOPCG6dCX6BSht44RZMRnxVrw4NdAA07lo6kd9fNT6ThCPql8Ia0a2EBDlbw%3D%3D&pageNo=1&schDate=20200409&schDeptCityCode=CJU&numOfRows=999
# {'serviceKey': 'Hl9nCtSJsJYpZKSXI1I4S3Ucr7gOPCG6dCX6BSht44RZMRnxVrw4NdAA07lo6kd9fNT6ThCPql8Ia0a2EBDlbw==', 'pageNo': '1', 'schDate': '20200409', 'schDeptCityCode': 'CJU', 'numOfRows': 999}
# http://openapi.airport.co.kr/service/rest/FlightScheduleList/getDflightScheduleList?serviceKey=Hl9nCtSJsJYpZKSXI1I4S3Ucr7gOPCG6dCX6BSht44RZMRnxVrw4NdAA07lo6kd9fNT6ThCPql8Ia0a2EBDlbw%3D%3D&pageNo=1&schDate=20200409&schArrvCityCode=CJU&numOfRows=999
# {'serviceKey': 'Hl9nCtSJsJYpZKSXI1I4S3Ucr7gOPCG6dCX6BSht44RZMRnxVrw4NdAA07lo6kd9fNT6ThCPql8Ia0a2EBDlbw==', 'pageNo': '1', 'schDate': '20200409', 'schArrvCityCode': 'CJU', 'numOfRows': 999}
# http://openapi.airport.co.kr/service/rest/FlightStatusList/getFlightStatusList?serviceKey=Hl9nCtSJsJYpZKSXI1I4S3Ucr7gOPCG6dCX6BSht44RZMRnxVrw4NdAA07lo6kd9fNT6ThCPql8Ia0a2EBDlbw%3D%3D&pageNo=1&schLineType=D&schAirCode=CJU&numOfRows=999
# {'serviceKey': 'Hl9nCtSJsJYpZKSXI1I4S3Ucr7gOPCG6dCX6BSht44RZMRnxVrw4NdAA07lo6kd9fNT6ThCPql8Ia0a2EBDlbw==', 'pageNo': '1', 'schLineType': 'D', 'schAirCode': 'CJU', 'numOfRows': 999}

# %%
departure_list
# Out:
# [{'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8900',
#   'arrival_time': '0740',
#   'departure_time': '0630',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-06-22T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8902',
#   'arrival_time': '0750',
#   'departure_time': '0640',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '진에어',
#   'arrival_city': '광주',
#   'flight_num': 'LJ592',
#   'arrival_time': '0810',
#   'departure_time': '0720',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어서울',
#   'arrival_city': '서울/김포',
#   'flight_num': 'RS902',
#   'arrival_time': '0840',
#   'departure_time': '0730',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '에어서울',
#   'arrival_city': '서울/김포',
#   'flight_num': 'RS902',
#   'arrival_time': '0845',
#   'departure_time': '0735',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW702',
#   'arrival_time': '0905',
#   'departure_time': '0755',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8904',
#   'arrival_time': '0905',
#   'departure_time': '0755',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '대구',
#   'flight_num': 'TW802',
#   'arrival_time': '0855',
#   'departure_time': '0800',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '이스타항공',
#   'arrival_city': '청주',
#   'flight_num': 'ZE702',
#   'arrival_time': '0900',
#   'departure_time': '0800',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '광주',
#   'flight_num': 'TW902',
#   'arrival_time': '0855',
#   'departure_time': '0805',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '플라이강원',
#   'arrival_city': '양양',
#   'flight_num': '4V502',
#   'arrival_time': '0925',
#   'departure_time': '0805',
#   'start_date': '2020-04-04T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8906',
#   'arrival_time': '0930',
#   'departure_time': '0820',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW704',
#   'arrival_time': '0935',
#   'departure_time': '0825',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '대구',
#   'flight_num': 'TW802',
#   'arrival_time': '0925',
#   'departure_time': '0825',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '부산/김해',
#   'flight_num': 'BX8100',
#   'arrival_time': '0930',
#   'departure_time': '0830',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '부산/김해',
#   'flight_num': 'BX8100',
#   'arrival_time': '0935',
#   'departure_time': '0830',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '광주',
#   'flight_num': 'OZ8140',
#   'arrival_time': '0925',
#   'departure_time': '0835',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-06-22T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW706',
#   'arrival_time': '0955',
#   'departure_time': '0845',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '제주항공',
#   'arrival_city': '서울/김포',
#   'flight_num': '7C136',
#   'arrival_time': '0955',
#   'departure_time': '0845',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '광주',
#   'flight_num': 'KE1902',
#   'arrival_time': '0935',
#   'departure_time': '0845',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '부산/김해',
#   'flight_num': 'KE1002',
#   'arrival_time': '0945',
#   'departure_time': '0845',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'KE1212',
#   'arrival_time': '1015',
#   'departure_time': '0905',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '진에어',
#   'arrival_city': '서울/김포',
#   'flight_num': 'LJ308',
#   'arrival_time': '1020',
#   'departure_time': '0910',
#   'start_date': '2020-04-06T00:00:00+09:00',
#   'end_date': '2020-04-09T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '에어부산',
#   'arrival_city': '부산/김해',
#   'flight_num': 'BX8106',
#   'arrival_time': '1010',
#   'departure_time': '0910',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'KE1212',
#   'arrival_time': '1020',
#   'departure_time': '0910',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '부산/김해',
#   'flight_num': 'BX8102',
#   'arrival_time': '1015',
#   'departure_time': '0915',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8914',
#   'arrival_time': '1030',
#   'departure_time': '0920',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '서울/김포',
#   'flight_num': 'BX8016',
#   'arrival_time': '1035',
#   'departure_time': '0925',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '에어부산',
#   'arrival_city': '서울/김포',
#   'flight_num': 'BX8016',
#   'arrival_time': '1045',
#   'departure_time': '0935',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '서울/김포',
#   'flight_num': 'BX8026',
#   'arrival_time': '1050',
#   'departure_time': '0940',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '제주항공',
#   'arrival_city': '서울/김포',
#   'flight_num': '7C104',
#   'arrival_time': '1055',
#   'departure_time': '0945',
#   'start_date': '2020-04-01T00:00:00+09:00',
#   'end_date': '2020-04-18T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW708',
#   'arrival_time': '1110',
#   'departure_time': '1000',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '청주',
#   'flight_num': 'KE1952',
#   'arrival_time': '1120',
#   'departure_time': '1010',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '제주항공',
#   'arrival_city': '서울/김포',
#   'flight_num': '7C106',
#   'arrival_time': '1120',
#   'departure_time': '1010',
#   'start_date': '2020-04-01T00:00:00+09:00',
#   'end_date': '2020-04-18T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '대한항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'KE1216',
#   'arrival_time': '1120',
#   'departure_time': '1010',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '여수',
#   'flight_num': 'OZ8196',
#   'arrival_time': '1105',
#   'departure_time': '1015',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-06-22T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '서울/김포',
#   'flight_num': 'BX8016',
#   'arrival_time': '1130',
#   'departure_time': '1020',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8920',
#   'arrival_time': '1130',
#   'departure_time': '1020',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '진에어',
#   'arrival_city': '부산/김해',
#   'flight_num': 'LJ562',
#   'arrival_time': '1130',
#   'departure_time': '1030',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '제주항공',
#   'arrival_city': '서울/김포',
#   'flight_num': '7C106',
#   'arrival_time': '1145',
#   'departure_time': '1035',
#   'start_date': '2020-03-30T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '부산/김해',
#   'flight_num': 'BX8104',
#   'arrival_time': '1140',
#   'departure_time': '1040',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '에어부산',
#   'arrival_city': '부산/김해',
#   'flight_num': 'BX8104',
#   'arrival_time': '1130',
#   'departure_time': '1040',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '진에어',
#   'arrival_city': '청주',
#   'flight_num': 'LJ584',
#   'arrival_time': '1150',
#   'departure_time': '1045',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '광주',
#   'flight_num': 'TW904',
#   'arrival_time': '1140',
#   'departure_time': '1050',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '제주항공',
#   'arrival_city': '서울/김포',
#   'flight_num': '7C108',
#   'arrival_time': '1200',
#   'departure_time': '1050',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어서울',
#   'arrival_city': '서울/김포',
#   'flight_num': 'RS904',
#   'arrival_time': '1210',
#   'departure_time': '1100',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW710',
#   'arrival_time': '1215',
#   'departure_time': '1105',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'KE1224',
#   'arrival_time': '1220',
#   'departure_time': '1110',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '광주',
#   'flight_num': 'OZ8142',
#   'arrival_time': '1205',
#   'departure_time': '1110',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-23T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '제주항공',
#   'arrival_city': '서울/김포',
#   'flight_num': '7C142',
#   'arrival_time': '1225',
#   'departure_time': '1115',
#   'start_date': '2020-04-04T00:00:00+09:00',
#   'end_date': '2020-04-18T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '제주항공',
#   'arrival_city': '서울/김포',
#   'flight_num': '7C142',
#   'arrival_time': '1225',
#   'departure_time': '1115',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '진에어',
#   'arrival_city': '서울/김포',
#   'flight_num': 'LJ314',
#   'arrival_time': '1250',
#   'departure_time': '1135',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'KE1226',
#   'arrival_time': '1245',
#   'departure_time': '1135',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '플라이강원',
#   'arrival_city': '양양',
#   'flight_num': '4V502',
#   'arrival_time': '1255',
#   'departure_time': '1135',
#   'start_date': '2020-03-30T00:00:00+09:00',
#   'end_date': '2020-10-19T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '대구',
#   'flight_num': 'TW9802',
#   'arrival_time': '1235',
#   'departure_time': '1135',
#   'start_date': '2020-04-03T00:00:00+09:00',
#   'end_date': '2020-04-26T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW712',
#   'arrival_time': '1245',
#   'departure_time': '1135',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW714',
#   'arrival_time': '1250',
#   'departure_time': '1140',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '제주항공',
#   'arrival_city': '서울/김포',
#   'flight_num': '7C112',
#   'arrival_time': '1250',
#   'departure_time': '1140',
#   'start_date': '2020-04-01T00:00:00+09:00',
#   'end_date': '2020-04-18T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '부산/김해',
#   'flight_num': 'KE1004',
#   'arrival_time': '1300',
#   'departure_time': '1200',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '플라이강원',
#   'arrival_city': '양양',
#   'flight_num': '4V502',
#   'arrival_time': '1325',
#   'departure_time': '1205',
#   'start_date': '2020-03-31T00:00:00+09:00',
#   'end_date': '2020-10-20T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8922',
#   'arrival_time': '1320',
#   'departure_time': '1210',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW716',
#   'arrival_time': '1325',
#   'departure_time': '1215',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '플라이강원',
#   'arrival_city': '양양',
#   'flight_num': '4V502',
#   'arrival_time': '1335',
#   'departure_time': '1215',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-23T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '제주항공',
#   'arrival_city': '서울/김포',
#   'flight_num': '7C154',
#   'arrival_time': '1330',
#   'departure_time': '1220',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '진에어',
#   'arrival_city': '서울/김포',
#   'flight_num': 'LJ316',
#   'arrival_time': '1345',
#   'departure_time': '1230',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '진에어',
#   'arrival_city': '부산/김해',
#   'flight_num': 'LJ564',
#   'arrival_time': '1340',
#   'departure_time': '1240',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW718',
#   'arrival_time': '1355',
#   'departure_time': '1245',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '진에어',
#   'arrival_city': '부산/김해',
#   'flight_num': 'LJ564',
#   'arrival_time': '1405',
#   'departure_time': '1250',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'KE1232',
#   'arrival_time': '1400',
#   'departure_time': '1250',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어서울',
#   'arrival_city': '서울/김포',
#   'flight_num': 'RS904',
#   'arrival_time': '1415',
#   'departure_time': '1305',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '플라이강원',
#   'arrival_city': '양양',
#   'flight_num': '4V502',
#   'arrival_time': '1425',
#   'departure_time': '1305',
#   'start_date': '2020-04-01T00:00:00+09:00',
#   'end_date': '2020-10-21T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8932',
#   'arrival_time': '1420',
#   'departure_time': '1310',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '광주',
#   'flight_num': 'OZ8144',
#   'arrival_time': '1405',
#   'departure_time': '1310',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-06-22T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '서울/김포',
#   'flight_num': 'BX8028',
#   'arrival_time': '1420',
#   'departure_time': '1320',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '광주',
#   'flight_num': 'TW906',
#   'arrival_time': '1415',
#   'departure_time': '1325',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '에어부산',
#   'arrival_city': '부산/김해',
#   'flight_num': 'BX8182',
#   'arrival_time': '1425',
#   'departure_time': '1325',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW720',
#   'arrival_time': '1440',
#   'departure_time': '1330',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '청주',
#   'flight_num': 'KE1954',
#   'arrival_time': '1450',
#   'departure_time': '1340',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '진에어',
#   'arrival_city': '서울/김포',
#   'flight_num': 'LJ312',
#   'arrival_time': '1500',
#   'departure_time': '1345',
#   'start_date': '2020-04-06T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '제주항공',
#   'arrival_city': '서울/김포',
#   'flight_num': '7C118',
#   'arrival_time': '1510',
#   'departure_time': '1400',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '제주항공',
#   'arrival_city': '부산/김해',
#   'flight_num': '7C508',
#   'arrival_time': '1500',
#   'departure_time': '1405',
#   'start_date': '2020-04-03T00:00:00+09:00',
#   'end_date': '2020-04-16T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8944',
#   'arrival_time': '1520',
#   'departure_time': '1410',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8948',
#   'arrival_time': '1530',
#   'departure_time': '1420',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-06-22T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'KE1242',
#   'arrival_time': '1540',
#   'departure_time': '1430',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '여수',
#   'flight_num': 'OZ8198',
#   'arrival_time': '1525',
#   'departure_time': '1435',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-06-22T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어서울',
#   'arrival_city': '서울/김포',
#   'flight_num': 'RS906',
#   'arrival_time': '1550',
#   'departure_time': '1440',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '대구',
#   'flight_num': 'TW804',
#   'arrival_time': '1550',
#   'departure_time': '1445',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '부산/김해',
#   'flight_num': 'BX8110',
#   'arrival_time': '1600',
#   'departure_time': '1455',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '부산/김해',
#   'flight_num': 'BX8110',
#   'arrival_time': '1605',
#   'departure_time': '1455',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '제주항공',
#   'arrival_city': '서울/김포',
#   'flight_num': '7C144',
#   'arrival_time': '1610',
#   'departure_time': '1500',
#   'start_date': '2020-04-04T00:00:00+09:00',
#   'end_date': '2020-04-18T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '제주항공',
#   'arrival_city': '서울/김포',
#   'flight_num': '7C144',
#   'arrival_time': '1610',
#   'departure_time': '1500',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '광주',
#   'flight_num': 'TW906',
#   'arrival_time': '1555',
#   'departure_time': '1505',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어서울',
#   'arrival_city': '서울/김포',
#   'flight_num': 'RS906',
#   'arrival_time': '1615',
#   'departure_time': '1505',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '청주',
#   'flight_num': 'OZ8234',
#   'arrival_time': '1620',
#   'departure_time': '1510',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW722',
#   'arrival_time': '1625',
#   'departure_time': '1515',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '제주항공',
#   'arrival_city': '부산/김해',
#   'flight_num': '7C510',
#   'arrival_time': '1620',
#   'departure_time': '1520',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '진에어',
#   'arrival_city': '청주',
#   'flight_num': 'LJ586',
#   'arrival_time': '1640',
#   'departure_time': '1525',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '진에어',
#   'arrival_city': '서울/김포',
#   'flight_num': 'LJ326',
#   'arrival_time': '1640',
#   'departure_time': '1530',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8950',
#   'arrival_time': '1650',
#   'departure_time': '1540',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW724',
#   'arrival_time': '1700',
#   'departure_time': '1550',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '대한항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'KE1248',
#   'arrival_time': '1700',
#   'departure_time': '1550',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8956',
#   'arrival_time': '1705',
#   'departure_time': '1555',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'KE1250',
#   'arrival_time': '1710',
#   'departure_time': '1600',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'KE1252',
#   'arrival_time': '1710',
#   'departure_time': '1600',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '진에어',
#   'arrival_city': '서울/김포',
#   'flight_num': 'LJ328',
#   'arrival_time': '1720',
#   'departure_time': '1605',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'KE1252',
#   'arrival_time': '1720',
#   'departure_time': '1610',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW726',
#   'arrival_time': '1730',
#   'departure_time': '1620',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '서울/김포',
#   'flight_num': 'BX8010',
#   'arrival_time': '1730',
#   'departure_time': '1620',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '제주항공',
#   'arrival_city': '서울/김포',
#   'flight_num': '7C120',
#   'arrival_time': '1735',
#   'departure_time': '1625',
#   'start_date': '2020-04-01T00:00:00+09:00',
#   'end_date': '2020-04-18T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '부산/김해',
#   'flight_num': 'BX8112',
#   'arrival_time': '1735',
#   'departure_time': '1630',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '에어부산',
#   'arrival_city': '부산/김해',
#   'flight_num': 'BX8112',
#   'arrival_time': '1730',
#   'departure_time': '1630',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '서울/김포',
#   'flight_num': 'BX8020',
#   'arrival_time': '1745',
#   'departure_time': '1635',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '광주',
#   'flight_num': 'OZ8146',
#   'arrival_time': '1725',
#   'departure_time': '1635',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-23T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '서울/김포',
#   'flight_num': 'BX8020',
#   'arrival_time': '1745',
#   'departure_time': '1635',
#   'start_date': '2020-03-31T00:00:00+09:00',
#   'end_date': '2020-06-23T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '제주항공',
#   'arrival_city': '광주',
#   'flight_num': '7C606',
#   'arrival_time': '1740',
#   'departure_time': '1650',
#   'start_date': '2020-04-01T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'KE1256',
#   'arrival_time': '1805',
#   'departure_time': '1655',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8964',
#   'arrival_time': '1805',
#   'departure_time': '1655',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '진에어',
#   'arrival_city': '서울/김포',
#   'flight_num': 'LJ330',
#   'arrival_time': '1810',
#   'departure_time': '1700',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8970',
#   'arrival_time': '1810',
#   'departure_time': '1700',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '부산/김해',
#   'flight_num': 'BX8132',
#   'arrival_time': '1800',
#   'departure_time': '1700',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW728',
#   'arrival_time': '1815',
#   'departure_time': '1705',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '진에어',
#   'arrival_city': '청주',
#   'flight_num': 'LJ558',
#   'arrival_time': '1820',
#   'departure_time': '1715',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW728',
#   'arrival_time': '1825',
#   'departure_time': '1715',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8964',
#   'arrival_time': '1830',
#   'departure_time': '1720',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '제주항공',
#   'arrival_city': '서울/김포',
#   'flight_num': '7C122',
#   'arrival_time': '1830',
#   'departure_time': '1720',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '진에어',
#   'arrival_city': '부산/김해',
#   'flight_num': 'LJ566',
#   'arrival_time': '1825',
#   'departure_time': '1725',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '진에어',
#   'arrival_city': '서울/김포',
#   'flight_num': 'LJ332',
#   'arrival_time': '1845',
#   'departure_time': '1735',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '제주항공',
#   'arrival_city': '청주',
#   'flight_num': '7C854',
#   'arrival_time': '1840',
#   'departure_time': '1735',
#   'start_date': '2020-04-01T00:00:00+09:00',
#   'end_date': '2020-04-09T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '부산/김해',
#   'flight_num': 'KE1008',
#   'arrival_time': '1835',
#   'departure_time': '1735',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8972',
#   'arrival_time': '1850',
#   'departure_time': '1740',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '광주',
#   'flight_num': 'OZ8148',
#   'arrival_time': '1840',
#   'departure_time': '1745',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-06-22T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '광주',
#   'flight_num': 'KE1908',
#   'arrival_time': '1845',
#   'departure_time': '1750',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '제주항공',
#   'arrival_city': '서울/김포',
#   'flight_num': '7C124',
#   'arrival_time': '1905',
#   'departure_time': '1755',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '대구',
#   'flight_num': 'TW806',
#   'arrival_time': '1905',
#   'departure_time': '1805',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '광주',
#   'flight_num': 'TW908',
#   'arrival_time': '1900',
#   'departure_time': '1810',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '부산/김해',
#   'flight_num': 'BX8116',
#   'arrival_time': '1930',
#   'departure_time': '1835',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '에어부산',
#   'arrival_city': '부산/김해',
#   'flight_num': 'BX8116',
#   'arrival_time': '1935',
#   'departure_time': '1835',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '제주항공',
#   'arrival_city': '서울/김포',
#   'flight_num': '7C146',
#   'arrival_time': '1950',
#   'departure_time': '1840',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-14T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '이스타항공',
#   'arrival_city': '청주',
#   'flight_num': 'ZE704',
#   'arrival_time': '1950',
#   'departure_time': '1845',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '제주항공',
#   'arrival_city': '부산/김해',
#   'flight_num': '7C514',
#   'arrival_time': '1930',
#   'departure_time': '1845',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '제주항공',
#   'arrival_city': '부산/김해',
#   'flight_num': '7C514',
#   'arrival_time': '1935',
#   'departure_time': '1845',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '에어서울',
#   'arrival_city': '서울/김포',
#   'flight_num': 'RS908',
#   'arrival_time': '2010',
#   'departure_time': '1900',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8980',
#   'arrival_time': '2010',
#   'departure_time': '1900',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'KE1268',
#   'arrival_time': '2010',
#   'departure_time': '1900',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '플라이강원',
#   'arrival_city': '양양',
#   'flight_num': '4V506',
#   'arrival_time': '2020',
#   'departure_time': '1900',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-20T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '진에어',
#   'arrival_city': '광주',
#   'flight_num': 'LJ594',
#   'arrival_time': '1955',
#   'departure_time': '1905',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '부산/김해',
#   'flight_num': 'BX8134',
#   'arrival_time': '2005',
#   'departure_time': '1905',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '에어부산',
#   'arrival_city': '부산/김해',
#   'flight_num': 'BX8134',
#   'arrival_time': '2000',
#   'departure_time': '1905',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '진에어',
#   'arrival_city': '부산/김해',
#   'flight_num': 'LJ568',
#   'arrival_time': '2005',
#   'departure_time': '1905',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '진에어',
#   'arrival_city': '부산/김해',
#   'flight_num': 'LJ568',
#   'arrival_time': '2000',
#   'departure_time': '1905',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '진에어',
#   'arrival_city': '부산/김해',
#   'flight_num': 'LJ568',
#   'arrival_time': '2010',
#   'departure_time': '1910',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '대구',
#   'flight_num': 'TW808',
#   'arrival_time': '2010',
#   'departure_time': '1910',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '플라이강원',
#   'arrival_city': '양양',
#   'flight_num': '4V506',
#   'arrival_time': '2035',
#   'departure_time': '1915',
#   'start_date': '2020-03-30T00:00:00+09:00',
#   'end_date': '2020-10-23T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '서울/김포',
#   'flight_num': 'BX8012',
#   'arrival_time': '2030',
#   'departure_time': '1920',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW730',
#   'arrival_time': '2035',
#   'departure_time': '1925',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW9732',
#   'arrival_time': '2105',
#   'departure_time': '1930',
#   'start_date': '2020-04-04T00:00:00+09:00',
#   'end_date': '2020-04-18T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8982',
#   'arrival_time': '2040',
#   'departure_time': '1930',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-06-22T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '에어서울',
#   'arrival_city': '서울/김포',
#   'flight_num': 'RS908',
#   'arrival_time': '2040',
#   'departure_time': '1930',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '에어서울',
#   'arrival_city': '서울/김포',
#   'flight_num': 'RS908',
#   'arrival_time': '2045',
#   'departure_time': '1935',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '에어부산',
#   'arrival_city': '부산/김해',
#   'flight_num': 'BX8138',
#   'arrival_time': '2030',
#   'departure_time': '1935',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '플라이강원',
#   'arrival_city': '양양',
#   'flight_num': '4V506',
#   'arrival_time': '2055',
#   'departure_time': '1935',
#   'start_date': '2020-04-04T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '에어서울',
#   'arrival_city': '서울/김포',
#   'flight_num': 'RS908',
#   'arrival_time': '2050',
#   'departure_time': '1940',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '에어서울',
#   'arrival_city': '서울/김포',
#   'flight_num': 'RS908',
#   'arrival_time': '2055',
#   'departure_time': '1945',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '에어부산',
#   'arrival_city': '서울/김포',
#   'flight_num': 'BX8018',
#   'arrival_time': '2100',
#   'departure_time': '1950',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8986',
#   'arrival_time': '2100',
#   'departure_time': '1950',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW732',
#   'arrival_time': '2105',
#   'departure_time': '1955',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '부산/김해',
#   'flight_num': 'BX8118',
#   'arrival_time': '2105',
#   'departure_time': '1955',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '서울/김포',
#   'flight_num': 'BX8024',
#   'arrival_time': '2120',
#   'departure_time': '2000',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '제주항공',
#   'arrival_city': '서울/김포',
#   'flight_num': '7C126',
#   'arrival_time': '2110',
#   'departure_time': '2000',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어서울',
#   'arrival_city': '서울/김포',
#   'flight_num': 'RS908',
#   'arrival_time': '2115',
#   'departure_time': '2005',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '제주항공',
#   'arrival_city': '부산/김해',
#   'flight_num': '7C516',
#   'arrival_time': '2105',
#   'departure_time': '2005',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어서울',
#   'arrival_city': '서울/김포',
#   'flight_num': 'RS908',
#   'arrival_time': '2115',
#   'departure_time': '2005',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW734',
#   'arrival_time': '2140',
#   'departure_time': '2030',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'KE1274',
#   'arrival_time': '2140',
#   'departure_time': '2030',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '청주',
#   'flight_num': 'OZ8236',
#   'arrival_time': '2140',
#   'departure_time': '2035',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-06-22T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '서울/김포',
#   'flight_num': 'BX8022',
#   'arrival_time': '2150',
#   'departure_time': '2040',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW734',
#   'arrival_time': '2155',
#   'departure_time': '2045',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '대한항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'KE1276',
#   'arrival_time': '2200',
#   'departure_time': '2050',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8996',
#   'arrival_time': '2205',
#   'departure_time': '2055',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-06-22T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'TW736',
#   'arrival_time': '2215',
#   'departure_time': '2105',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'KE1278',
#   'arrival_time': '2215',
#   'departure_time': '2105',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '대한항공',
#   'arrival_city': '부산/김해',
#   'flight_num': 'KE1018',
#   'arrival_time': '2205',
#   'departure_time': '2105',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '진에어',
#   'arrival_city': '서울/김포',
#   'flight_num': 'LJ338',
#   'arrival_time': '2220',
#   'departure_time': '2110',
#   'start_date': '2020-04-06T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '제주항공',
#   'arrival_city': '서울/김포',
#   'flight_num': '7C158',
#   'arrival_time': '2220',
#   'departure_time': '2110',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '아시아나항공',
#   'arrival_city': '서울/김포',
#   'flight_num': 'OZ8998',
#   'arrival_time': '2220',
#   'departure_time': '2110',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-06-22T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '대구',
#   'flight_num': 'TW810',
#   'arrival_time': '2210',
#   'departure_time': '2110',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '에어부산',
#   'arrival_city': '서울/김포',
#   'flight_num': 'BX8014',
#   'arrival_time': '2230',
#   'departure_time': '2120',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '제주항공',
#   'arrival_city': '서울/김포',
#   'flight_num': '7C134',
#   'arrival_time': '2230',
#   'departure_time': '2120',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '이스타항공',
#   'arrival_city': '청주',
#   'flight_num': 'ZE706',
#   'arrival_time': '2230',
#   'departure_time': '2125',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '진에어',
#   'arrival_city': '청주',
#   'flight_num': 'LJ560',
#   'arrival_time': '2240',
#   'departure_time': '2130',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-04-25T00:00:00+09:00',
#   'friday_yn': 'Y'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '대구',
#   'flight_num': 'TW9816',
#   'arrival_time': '2305',
#   'departure_time': '2155',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'N'},
#  {'airline_name': '티웨이항공',
#   'arrival_city': '대구',
#   'flight_num': 'TW9816',
#   'arrival_time': '2305',
#   'departure_time': '2205',
#   'start_date': '2020-03-29T00:00:00+09:00',
#   'end_date': '2020-10-24T00:00:00+09:00',
#   'friday_yn': 'Y'}]

# %%
print(departure_list[0])
print(arrival_list[0])
print(status_list[0])
print(len(departure_list))
print(len(arrival_list))
print(len(status_list))
# Out:
# {'airline_name': '아시아나항공', 'arrival_city': '서울/김포', 'flight_num': 'OZ8900', 'arrival_time': '0740', 'departure_time': '0630', 'start_date': '2020-03-29T00:00:00+09:00', 'end_date': '2020-06-22T00:00:00+09:00', 'friday_yn': 'Y'}
# {'airline_name': '에어서울', 'departure_city': '서울/김포', 'flight_num': 'RS901', 'arrival_time': '0700', 'departure_time': '0600', 'start_date': '2020-03-29T00:00:00+09:00', 'end_date': '2020-10-24T00:00:00+09:00', 'friday_yn': 'N'}
# {'flight_num': 'OZ8900', 'airline_name': '아시아나항공', 'airport_code': 'CJU', 'city_code': 'GMP', 'arrived_airport_name': '서울/김포', 'boarding_airport_name': '제주', 'scheduled_time': '0630', 'estimated_time': '0640', 'inout_code': 'O', 'flight_status_eng': 'DEPARTED', 'flight_status_kor': '출발'}
# 192
# 217
# 196
